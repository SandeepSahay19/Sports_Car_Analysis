# %% [markdown]
# # SPORTS_CAR_ANALYSIS

# %% [markdown]
# ### The Dataset contains Car make ,Car Model, Year, Engine size (L), Horsepower, Torque (lb-ft), (0-60) MPH Time (seconds), Price (in USD). As a Data Analyst I have to answer stakeholder questions below. I will write SQL queries on MySQL workbench for finding insights.

# %% [markdown]
# ## 1. What are the top 10 car makes by the number of models available in the dataset?

# %% [markdown]
# ![2023-05-07.png](attachment:2023-05-07.png)

# %% [markdown]
# ## 2.What is the average horsepower of all cars in the dataset?

# %% [markdown]
# ![2023-05-07%20%281%29.png](attachment:2023-05-07%20%281%29.png)

# %% [markdown]
# ## 3.What is the most popular car Model in the dataset?

# %% [markdown]
# ![2023-05-07%20%282%29.png](attachment:2023-05-07%20%282%29.png)

# %% [markdown]
# ## 4. What is the total number of cars in the dataset?

# %% [markdown]
# ![2023-05-07%20%284%29.png](attachment:2023-05-07%20%284%29.png)

# %% [markdown]
# ## 5.What is the fastest car in terms of 0-60 MPH time and how much does it cost?

# %% [markdown]
# ![2023-05-07%20%283%29.png](attachment:2023-05-07%20%283%29.png)

# %% [markdown]
# ## 6.What is the total number of different car models in the dataset?

# %% [markdown]
# ![2023-05-07%20%285%29.png](attachment:2023-05-07%20%285%29.png)
